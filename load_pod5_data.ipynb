# %%
import pod5

# %%
directory = "/home/vincent/projects/pod5view/pod5_files"

# %%
pod5_files = pod5.DatasetReader(directory)

# %%
files = pod5_files.paths

# %%
x = pod5_files.reads(files[0])

# %%
pod5_files.get_reader(files[0]).num_reads
# Out:
# 4000

# %%
reads_in_files = dict(zip(files, [pod5_files.get_reader(file).read_ids for file in files]))

# %%
reads_in_files
# Out:
# {PosixPath('/home/vincent/projects/pod5view/pod5_files/PAU44140_pass_8b98bb7f_f9191d76_2.pod5'): ['6a9779bf-b3a1-4fa3-aea8-a28a6dd2a118',
#   '280f645d-2c37-4959-ab4c-1414b475524f',
#   '5b622590-c35d-4422-9729-0e009130c3fd',
#   '2c8294b4-e915-44b6-926a-af8417796c5b',
#   '99049cd0-d305-469a-aa1c-a8a0b1ddaedb',
#   '0f3080d3-9c38-4c76-8db8-c3b33afda6b7',
#   '1934e569-c5b3-4f22-959b-c3fe53b195ec',
#   '94b3023f-85d7-4e33-9377-1cd515102118',
#   'c37476ec-462a-45c6-90cb-027f2beb5ab7',
#   '4edfe53b-2ee3-4954-9d1a-e9b00fdcf7e0',
#   '45617fc9-be15-439e-bfca-aaccd97bfd56',
#   'e5397930-cb4e-4371-9c27-d0695e0f5a1b',
#   'fce00837-dec8-4e67-8015-5e2b5780935d',
#   '729a72e3-6c10-4c64-98fd-b151dd82d573',
#   'b35c65db-ff0b-4171-9888-a0d2cf917977',
#   '0c136fd5-6d3c-4f08-a5a5-0565edb5ca7e',
#   '64120584-78a6-41bd-a374-cc8627cbda45',
#   '471fec07-1074-4de6-8073-0ab4c8d39fe2',
#   '03e5bb43-de02-46bb-8187-cf182cac071c',
#   '5ab4a8dd-d14f-4b7c-8db8-c8d242c9adc1',
# ...

# %%
{
    "path1": ["wdawd", "dawfawf", "dfagesg"],
    "path2": ["hthhf", "gth", "hrdgesf"],
    "path3": ["htdrgerd", "öokjöl", "opijl"]
}

# %%
str(files[0])
# Out:
# '/home/vincent/projects/pod5view/pod5_files/PAU44140_pass_8b98bb7f_f9191d76_2.pod5'
